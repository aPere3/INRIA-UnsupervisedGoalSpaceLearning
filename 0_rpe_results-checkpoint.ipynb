# %% [markdown]
# # Random Parameterization Exploration

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets
# %matplotlib notebook
import pickle
import os
import json
import pprint
import warnings
warnings.filterwarnings('ignore')
from itertools import *
import scipy.stats
from tqdm import tqdm_notebook as tqdm
import skl_groups
from skl_groups.divergences import KNNDivergenceEstimator
from skl_groups.features import Features

# %%
ls
# Out:
# 0_comparison-checkpoint.ipynb
# 0_comparison.ipynb
# 0_rge_fi_results-checkpoint.ipynb
# 0_rge_fi_results.ipynb
# 0_rge_rep_results-checkpoint.ipynb
# 0_rge_rep_results.ipynb
# 0_rpe_results-checkpoint.ipynb
# 0_rpe_results.ipynb
# dataset2.pkl
# dataset.pkl
# Figures/
# Rge-Fi Armarrow 2017-12-12 16:12:30.912637/
# Rge-Fi Armarrow 2017-12-13 17:47:54.718545/
# Rge-Fi Armarrow 2017-12-14 08:39:46.659495/
# Rge-Fi Armarrow 2017-12-14 17:43:02.793836/
# Rge-Fi Armball 2017-12-12 16:12:30.912629/
# Rge-Fi Armball 2017-12-13 17:47:54.718536/
# Rge-Fi Armball 2017-12-14 08:39:46.659488/
# Rge-Fi Armball 2017-12-14 17:43:02.793828/
# Rge-Rep Ae Armarrow 2017-12-12 16:12:30.912657/
# Rge-Rep Ae Armarrow 2017-12-12 16:12:30.912752/
# Rge-Rep Ae Armarrow 2017-12-13 17:47:54.718568/
# Rge-Rep Ae Armarrow 2017-12-13 17:47:54.718672/
# Rge-Rep Ae Armarrow 2017-12-14 08:39:46.659512/
# Rge-Rep Ae Armarrow 2017-12-14 08:39:46.659592/
# Rge-Rep Ae Armarrow 2017-12-14 17:43:02.793856/
# Rge-Rep Ae Armarrow 2017-12-14 17:43:02.793948/
# Rge-Rep Ae Armarrow 2017-12-18 17:35:33.896193/
# Rge-Rep Ae Armarrow 2017-12-18 17:35:33.896340/
# Rge-Rep Ae Armarrow 2017-12-18 17:35:33.896464/
# Rge-Rep Ae Armarrow 2017-12-18 17:35:33.896583/
# Rge-Rep Ae Armarrow 2017-12-18 17:35:33.896702/
# Rge-Rep Ae Armarrow 2018-01-03 09:04:59.583792/
# Rge-Rep Ae Armarrow 2018-01-03 09:05:30.801232/
# Rge-Rep Ae Armarrow 2018-01-03 09:05:30.801296/
# Rge-Rep Ae Armarrow 2018-01-03 09:05:30.801334/
# Rge-Rep Ae Armarrow 2018-01-03 09:05:30.801377/
# Rge-Rep Ae Armarrow 2018-01-03 09:05:30.801413/
# Rge-Rep Ae Armarrow 2018-01-03 15:24:17.790254/
# Rge-Rep Ae Armarrow 2018-01-03 15:24:17.790296/
# Rge-Rep Ae Armarrow 2018-01-03 15:24:17.790329/
# Rge-Rep Ae Armarrow 2018-01-03 15:24:17.790362/
# Rge-Rep Ae Armarrow 2018-01-03 15:24:17.790398/
# Rge-Rep Ae Armball 2017-12-12 16:12:30.912647/
# Rge-Rep Ae Armball 2017-12-12 16:12:30.912744/
# Rge-Rep Ae Armball 2017-12-13 17:47:54.718557/
# Rge-Rep Ae Armball 2017-12-13 17:47:54.718663/
# Rge-Rep Ae Armball 2017-12-14 08:39:46.659504/
# Rge-Rep Ae Armball 2017-12-14 08:39:46.659585/
# Rge-Rep Ae Armball 2017-12-14 17:43:02.793846/
# Rge-Rep Ae Armball 2017-12-14 17:43:02.793940/
# Rge-Rep Ae Armball 2017-12-18 17:35:33.896139/
# Rge-Rep Ae Armball 2017-12-18 17:35:33.896327/
# Rge-Rep Ae Armball 2017-12-18 17:35:33.896453/
# Rge-Rep Ae Armball 2017-12-18 17:35:33.896572/
# Rge-Rep Ae Armball 2017-12-18 17:35:33.896693/
# Rge-Rep Isomap Armarrow 2017-12-12 16:12:30.912704/
# Rge-Rep Isomap Armarrow 2017-12-12 16:12:30.912802/
# Rge-Rep Isomap Armarrow 2017-12-13 17:47:54.718619/
# Rge-Rep Isomap Armarrow 2017-12-13 17:47:54.718728/
# Rge-Rep Isomap Armarrow 2017-12-14 08:39:46.659552/
# Rge-Rep Isomap Armarrow 2017-12-14 08:39:46.659636/
# Rge-Rep Isomap Armarrow 2017-12-14 17:43:02.793901/
# Rge-Rep Isomap Armarrow 2017-12-14 17:43:02.793996/
# Rge-Rep Isomap Armarrow 2017-12-18 17:35:33.896258/
# Rge-Rep Isomap Armarrow 2017-12-18 17:35:33.896396/
# Rge-Rep Isomap Armarrow 2017-12-18 17:35:33.896518/
# Rge-Rep Isomap Armarrow 2017-12-18 17:35:33.896638/
# Rge-Rep Isomap Armarrow 2017-12-18 17:35:33.896757/
# Rge-Rep Isomap Armarrow 2018-01-03 09:05:30.801274/
# Rge-Rep Isomap Armarrow 2018-01-03 09:05:30.801314/
# Rge-Rep Isomap Armarrow 2018-01-03 09:05:30.801358/
# Rge-Rep Isomap Armarrow 2018-01-03 09:05:30.801395/
# Rge-Rep Isomap Armarrow 2018-01-03 09:05:30.801431/
# Rge-Rep Isomap Armarrow 2018-01-03 15:24:17.790282/
# Rge-Rep Isomap Armarrow 2018-01-03 15:24:17.790315/
# Rge-Rep Isomap Armarrow 2018-01-03 15:24:17.790349/
# Rge-Rep Isomap Armarrow 2018-01-03 15:24:17.790381/
# Rge-Rep Isomap Armarrow 2018-01-03 15:24:17.790419/
# Rge-Rep Isomap Armball 2017-12-12 16:12:30.912696/
# Rge-Rep Isomap Armball 2017-12-12 16:12:30.912795/
# Rge-Rep Isomap Armball 2017-12-13 17:47:54.718611/
# Rge-Rep Isomap Armball 2017-12-13 17:47:54.718719/
# Rge-Rep Isomap Armball 2017-12-14 08:39:46.659545/
# Rge-Rep Isomap Armball 2017-12-14 08:39:46.659629/
# Rge-Rep Isomap Armball 2017-12-14 17:43:02.793894/
# Rge-Rep Isomap Armball 2017-12-14 17:43:02.793989/
# Rge-Rep Isomap Armball 2017-12-18 17:35:33.896248/
# Rge-Rep Isomap Armball 2017-12-18 17:35:33.896386/
# Rge-Rep Isomap Armball 2017-12-18 17:35:33.896509/
# Rge-Rep Isomap Armball 2017-12-18 17:35:33.896629/
# Rge-Rep Isomap Armball 2017-12-18 17:35:33.896748/
# Rge-Rep Pca Armarrow 2017-12-12 16:12:30.912719/
# Rge-Rep Pca Armarrow 2017-12-12 16:12:30.912864/
# Rge-Rep Pca Armarrow 2017-12-13 17:47:54.718636/
# Rge-Rep Pca Armarrow 2017-12-13 17:47:54.718793/
# Rge-Rep Pca Armarrow 2017-12-14 08:39:46.659564/
# Rge-Rep Pca Armarrow 2017-12-14 08:39:46.659692/
# Rge-Rep Pca Armarrow 2017-12-14 17:43:02.793916/
# Rge-Rep Pca Armarrow 2017-12-14 17:43:02.794050/
# Rge-Rep Pca Armarrow 2017-12-18 17:35:33.896276/
# Rge-Rep Pca Armarrow 2017-12-18 17:35:33.896414/
# Rge-Rep Pca Armarrow 2017-12-18 17:35:33.896537/
# Rge-Rep Pca Armarrow 2017-12-18 17:35:33.896656/
# Rge-Rep Pca Armarrow 2017-12-18 17:35:33.896776/
# Rge-Rep Pca Armarrow 2018-01-03 09:05:30.801285/
# Rge-Rep Pca Armarrow 2018-01-03 09:05:30.801324/
# Rge-Rep Pca Armarrow 2018-01-03 09:05:30.801367/
# Rge-Rep Pca Armarrow 2018-01-03 09:05:30.801404/
# Rge-Rep Pca Armarrow 2018-01-03 09:05:30.801441/
# Rge-Rep Pca Armarrow 2018-01-03 15:24:17.790289/
# Rge-Rep Pca Armarrow 2018-01-03 15:24:17.790322/
# Rge-Rep Pca Armarrow 2018-01-03 15:24:17.790355/
# Rge-Rep Pca Armarrow 2018-01-03 15:24:17.790391/
# Rge-Rep Pca Armarrow 2018-01-03 15:24:17.790427/
# Rge-Rep Pca Armball 2017-12-12 16:12:30.912711/
# Rge-Rep Pca Armball 2017-12-12 16:12:30.912854/
# Rge-Rep Pca Armball 2017-12-13 17:47:54.718627/
# Rge-Rep Pca Armball 2017-12-13 17:47:54.718781/
# Rge-Rep Pca Armball 2017-12-14 08:39:46.659558/
# Rge-Rep Pca Armball 2017-12-14 08:39:46.659683/
# Rge-Rep Pca Armball 2017-12-14 17:43:02.793909/
# Rge-Rep Pca Armball 2017-12-14 17:43:02.794041/
# Rge-Rep Pca Armball 2017-12-18 17:35:33.896267/
# Rge-Rep Pca Armball 2017-12-18 17:35:33.896405/
# Rge-Rep Pca Armball 2017-12-18 17:35:33.896528/
# Rge-Rep Pca Armball 2017-12-18 17:35:33.896647/
# Rge-Rep Pca Armball 2017-12-18 17:35:33.896767/
# Rge-Rep Rfvae Armarrow 2017-12-12 16:12:30.912688/
# Rge-Rep Rfvae Armarrow 2017-12-12 16:12:30.912782/
# Rge-Rep Rfvae Armarrow 2017-12-13 17:47:54.718602/
# Rge-Rep Rfvae Armarrow 2017-12-13 17:47:54.718705/
# Rge-Rep Rfvae Armarrow 2017-12-14 08:39:46.659538/
# Rge-Rep Rfvae Armarrow 2017-12-14 08:39:46.659618/
# Rge-Rep Rfvae Armarrow 2017-12-14 17:43:02.793886/
# Rge-Rep Rfvae Armarrow 2017-12-14 17:43:02.793978/
# Rge-Rep Rfvae Armarrow 2017-12-18 17:35:33.896239/
# Rge-Rep Rfvae Armarrow 2017-12-18 17:35:33.896377/
# Rge-Rep Rfvae Armarrow 2017-12-18 17:35:33.896500/
# Rge-Rep Rfvae Armarrow 2017-12-18 17:35:33.896620/
# Rge-Rep Rfvae Armarrow 2017-12-18 17:35:33.896739/
# Rge-Rep Rfvae Armarrow 2018-01-03 09:05:30.801261/
# Rge-Rep Rfvae Armarrow 2018-01-03 09:05:30.801305/
# Rge-Rep Rfvae Armarrow 2018-01-03 09:05:30.801348/
# Rge-Rep Rfvae Armarrow 2018-01-03 09:05:30.801386/
# Rge-Rep Rfvae Armarrow 2018-01-03 09:05:30.801422/
# Rge-Rep Rfvae Armarrow 2018-01-03 15:24:17.790275/
# Rge-Rep Rfvae Armarrow 2018-01-03 15:24:17.790308/
# Rge-Rep Rfvae Armarrow 2018-01-03 15:24:17.790342/
# Rge-Rep Rfvae Armarrow 2018-01-03 15:24:17.790375/
# Rge-Rep Rfvae Armarrow 2018-01-03 15:24:17.790412/
# Rge-Rep Rfvae Armball 2017-12-12 16:12:30.912680/
# Rge-Rep Rfvae Armball 2017-12-12 16:12:30.912774/
# Rge-Rep Rfvae Armball 2017-12-13 17:47:54.718593/
# Rge-Rep Rfvae Armball 2017-12-13 17:47:54.718696/
# Rge-Rep Rfvae Armball 2017-12-14 08:39:46.659532/
# Rge-Rep Rfvae Armball 2017-12-14 08:39:46.659610/
# Rge-Rep Rfvae Armball 2017-12-14 17:43:02.793879/
# Rge-Rep Rfvae Armball 2017-12-14 17:43:02.793970/
# Rge-Rep Rfvae Armball 2017-12-18 17:35:33.896229/
# Rge-Rep Rfvae Armball 2017-12-18 17:35:33.896368/
# Rge-Rep Rfvae Armball 2017-12-18 17:35:33.896491/
# Rge-Rep Rfvae Armball 2017-12-18 17:35:33.896610/
# Rge-Rep Rfvae Armball 2017-12-18 17:35:33.896730/
# Rge-Rep Vae Armarrow 2017-12-12 16:12:30.912673/
# Rge-Rep Vae Armarrow 2017-12-12 16:12:30.912767/
# Rge-Rep Vae Armarrow 2017-12-13 17:47:54.718585/
# Rge-Rep Vae Armarrow 2017-12-13 17:47:54.718688/
# Rge-Rep Vae Armarrow 2017-12-13 17:47:54.718811/
# Rge-Rep Vae Armarrow 2017-12-14 08:39:46.659525/
# Rge-Rep Vae Armarrow 2017-12-14 08:39:46.659604/
# Rge-Rep Vae Armarrow 2017-12-14 08:39:46.659706/
# Rge-Rep Vae Armarrow 2017-12-14 17:43:02.793871/
# Rge-Rep Vae Armarrow 2017-12-14 17:43:02.793932/
# Rge-Rep Vae Armarrow 2017-12-14 17:43:02.793963/
# Rge-Rep Vae Armarrow 2017-12-14 17:43:02.794065/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896219/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896296/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896359/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896433/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896482/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896556/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896601/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896681/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896721/
# Rge-Rep Vae Armarrow 2017-12-18 17:35:33.896800/
# Rge-Rep Vae Armarrow 2017-12-20 15:59:49.019583/
# Rge-Rep Vae Armarrow 2017-12-20 15:59:49.019609/
# Rge-Rep Vae Armarrow 2017-12-20 15:59:49.019627/
# Rge-Rep Vae Armarrow 2017-12-20 15:59:49.019645/
# Rge-Rep Vae Armarrow 2017-12-20 15:59:49.019662/
# Rge-Rep Vae Armarrow 2018-01-02 16:29:20.823311/
# Rge-Rep Vae Armarrow 2018-01-02 16:29:20.823336/
# Rge-Rep Vae Armarrow 2018-01-02 16:29:20.823347/
# Rge-Rep Vae Armarrow 2018-01-02 16:29:20.823355/
# Rge-Rep Vae Armarrow 2018-01-02 16:29:20.823363/
# Rge-Rep Vae Armarrow 2018-01-03 15:24:17.790270/
# Rge-Rep Vae Armarrow 2018-01-03 15:24:17.790302/
# Rge-Rep Vae Armarrow 2018-01-03 15:24:17.790336/
# Rge-Rep Vae Armarrow 2018-01-03 15:24:17.790368/
# Rge-Rep Vae Armarrow 2018-01-03 15:24:17.790404/
# Rge-Rep Vae Armball 2017-12-12 16:12:30.912665/
# Rge-Rep Vae Armball 2017-12-12 16:12:30.912711/
# Rge-Rep Vae Armball 2017-12-12 16:12:30.912759/
# Rge-Rep Vae Armball 2017-12-13 17:47:54.718577/
# Rge-Rep Vae Armball 2017-12-13 17:47:54.718680/
# Rge-Rep Vae Armball 2017-12-13 17:47:54.718802/
# Rge-Rep Vae Armball 2017-12-14 08:39:46.659519/
# Rge-Rep Vae Armball 2017-12-14 08:39:46.659598/
# Rge-Rep Vae Armball 2017-12-14 08:39:46.659699/
# Rge-Rep Vae Armball 2017-12-14 17:43:02.793864/
# Rge-Rep Vae Armball 2017-12-14 17:43:02.793924/
# Rge-Rep Vae Armball 2017-12-14 17:43:02.793955/
# Rge-Rep Vae Armball 2017-12-14 17:43:02.794058/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896209/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896286/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896350/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896424/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896473/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896546/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896592/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896666/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896712/
# Rge-Rep Vae Armball 2017-12-18 17:35:33.896785/
# Rge-Rep Vae Armball 2017-12-20 15:59:49.019529/
# Rge-Rep Vae Armball 2017-12-20 15:59:49.019598/
# Rge-Rep Vae Armball 2017-12-20 15:59:49.019618/
# Rge-Rep Vae Armball 2017-12-20 15:59:49.019636/
# Rge-Rep Vae Armball 2017-12-20 15:59:49.019654/
# Rpe Armarrow 2017-12-12 16:12:30.912618/
# Rpe Armarrow 2017-12-13 17:47:54.718524/
# Rpe Armarrow 2017-12-14 08:39:46.659479/
# Rpe Armarrow 2017-12-14 17:43:02.793818/
# Rpe Armball 2017-12-12 16:12:30.912596/
# Rpe Armball 2017-12-13 17:47:54.718501/
# Rpe Armball 2017-12-14 08:39:46.659459/
# Rpe Armball 2017-12-14 17:43:02.793797/
# test.png*

# %% [markdown]
# ## Config

# %%
path = "Rpe Armball 2017-12-14 08:39:46.659459/"
with open(os.path.join(path, "config.json")) as f:
    config = json.load(f)
pprint.pprint(config)
# Out:
# {u'environment': u'armball',
#  u'explo_ratio': 0.05,
#  u'name': u'Rpe Armball 2017-12-14 08:39:46.659459',
#  u'nb_bins_exploration_ratio': 10,
#  u'nb_exploration_iterations': 5000,
#  u'nb_period_callback': 10,
#  u'nb_samples': 10000,
#  u'nb_samples_divergence': 1000,
#  u'nb_samples_manifold': 1000,
#  u'nb_samples_mse': 100,
#  u'norder': [1, 1],
#  u'nstate': 2,
#  u'path': u'results/Rpe Armball 2017-12-14 08:39:46.659459',
#  u'test': False,
#  u'verbose': False}

# %% [markdown]
# ### Training States

# %%
states = np.load(os.path.join(path, 'samples_states.npy'))
print("State Space Size: %s"%(states.shape[-1]))
fig = plt.figure(figsize=(9,9))
plt.scatter(states[:,0], states[:,1])
# Out:
# State Space Size: 2
# <img src="data:image/png;base64,..." width="900">

# %%
n_states=states.shape[-1]
fig, ax = plt.subplots(n_states,n_states, figsize=(9,9))
for i in range(n_states**2):
    ax[i%n_states, i/n_states].scatter(states[:,i%n_states], states[:,i/n_states], s=.05)
    ax[i%n_states, i/n_states].axis('off')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ### Training Geodesics

# %%
geodesics = np.load(os.path.join(path, 'samples_geodesics.npy'))
print("Embedded Size: %s"%(geodesics.shape[-1]))
fig = plt.figure(figsize=(9,9))
plt.scatter(geodesics[:,0], geodesics[:,1])
print(geodesics.shape)
# Out:
# Embedded Size: 2
# <img src="data:image/png;base64,..." width="900">
# (1000, 2)

# %%
n_geodesics=geodesics.shape[-1]
fig, ax = plt.subplots(n_geodesics,n_geodesics, figsize=(9,9))
for i in range(n_geodesics**2):
    ax[i%n_geodesics, i/n_geodesics].scatter(geodesics[:,i%n_geodesics], geodesics[:,i/n_geodesics], s=.05)
    ax[i%n_geodesics, i/n_geodesics].axis('off')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Exploration Dynamics

# %% [markdown]
# ### Location Explored

# %%
with open(os.path.join(path, "explored_states_history.pkl"), 'rb') as f:
    explored_states_history = pickle.load(f)
print("Number of callbacks: %s"%len(explored_states_history))
# Out:
# Number of callbacks: 499

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(1, 1, 1)
scatt = ax.scatter(explored_states_history[498][:,0], explored_states_history[498][:,1])
ax
def update(epoch):
    scatt.set_offsets(explored_states_history[epoch][:,0:2])
    fig.canvas.draw()
ipywidgets.interact(update, epoch=(0, 498));
# Out:
# <img src="data:image/png;base64,..." width="900">
# A Jupyter Widget

# %% [markdown]
# ### Evolution of KDE

# %%
def kde_scipy( vals1, vals2, (a,b), (c,d), N ):

    #vals1, vals2 are the values of two variables (columns)
    #(a,b) interval for vals1; usually larger than (np.min(vals1), np.max(vals1))
    #(c,d) -"-          vals2 

    x=np.linspace(a,b,N)
    y=np.linspace(c,d,N)
    X,Y=np.meshgrid(x,y)
    positions = np.vstack([Y.ravel(), X.ravel()])

    values = np.vstack([vals1, vals2])
    kernel = scipy.stats.gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)

    return [x, y, Z]

# %%
map_size = 100
kdes = np.zeros((49, map_size, map_size))
for i in tqdm(range(49)):
    try:
        states = explored_states_history[i*10]
        idx = np.where(np.logical_not(np.isclose(states, [0.6, 0.6, 0.6], atol=1e-4)))[0]
        states = states[idx]
        x, y, z = kde_scipy(states[:,0],
                            states[:,1], 
                            (-1, 1), (-1, 1), map_size)
        kdes[i] = z
    except:
        pass
# Out:
# A Jupyter Widget

# %%
fig = plt.figure(figsize=(9,9))
ax = fig.add_subplot(1, 1, 1)
imsh = ax.imshow(kdes[48])
def update(epoch):
    imsh.set_data(kdes[epoch])
    fig.canvas.draw()
ipywidgets.interact(update, epoch=(0, 48))
# Out:
# <img src="data:image/png;base64,..." width="900">
# A Jupyter Widget
# <function __main__.update>

# %% [markdown]
# ### Evolution of KL-Div with attainable points.

# %%
def divergence_estimation(X_s, X_l, k=10):

    div = KNNDivergenceEstimator(div_funcs=['kl'], Ks=[k], n_jobs=4, clamp=True, do_sym = 1)
    X_s = X_s.astype(np.float32)
    X_l = X_l.astype(np.float32)
    f_s = Features(X_s, n_pts=[X_s.shape[0]])
    f_l = Features(X_l, n_pts=[X_l.shape[0]])
    div.fit(X=f_s)
    kls = div.transform(X=f_l).squeeze()

    return kls

def sample_in_attainable(nb_points, env):
    
    if env == 'armball':
        i = 0
        X = np.ndarray((nb_points, 2))
        while not i == nb_points:
            sample = np.random.uniform(-1, 1, 2)
            if np.linalg.norm(sample, ord=2) >1.:
                continue
            X[i] = sample
            i += 1
        return X
        
    if env == 'armarrow':
        i = 0
        X = np.ndarray((nb_points, 3))
        while not i == nb_points:
            sample = np.random.uniform(-1, 1, 3)
            if np.linalg.norm(sample[0:2], ord=2) > 1.:
                continue
            X[i] = sample
            i += 1
        return X

# %%
with open(os.path.join(path, "explored_states_history.pkl"), 'rb') as f:
    explored_states_history = pickle.load(f)
print("Number of callbacks: %s"%len(explored_states_history))
# Out:
# Number of callbacks: 499

# %%
kls = np.zeros((49,2))
X_real = sample_in_attainable(explored_states_history[498].shape[0], 'armball')
for i in tqdm(range(49)):    
    kls[i] = divergence_estimation(X_real, explored_states_history[i*10], k=10)
# Out:
# A Jupyter Widget

# %%
plt.figure(figsize=(9,9))
plt.plot(kls[:,0])
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig = plt.figure(figsize=(9.5,3))
plt.title("RGE-EFR - ArmBall")

ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(kls,linewidth=1., color='royalblue')
ax1.tick_params(axis='y', colors='royalblue')
ax1.set_ylim(3.5, 10.)
ax1.set_yticks(np.linspace(3.5,10.,6))
ax1.set_xlim(0., 50.)
ax1.set_xlabel("Exploration epochs (x100)")
ax1.set_ylabel("KLC", color='royalblue')
ax1.add_line(matplotlib.lines.Line2D([5,5],   [kls[5]+.05,7], linewidth=1))
ax1.add_line(matplotlib.lines.Line2D([15,15], [kls[15]+.05,7], linewidth=1))
ax1.add_line(matplotlib.lines.Line2D([25,25], [kls[25]+.05,7], linewidth=1))
ax1.add_line(matplotlib.lines.Line2D([35,35], [kls[35]+.05,7], linewidth=1))
ax1.add_line(matplotlib.lines.Line2D([45,45], [kls[45]+.05,7], linewidth=1))
points = [5,15,25,35,45]
ax1.scatter(points, kls[points])

ax1_2 = ax1.twinx()
ax1_2.locator_params(axis='y', nticks=6)
ax1_2.plot(expl, linewidth=1., c='mediumorchid')
ax1_2.tick_params(axis='y', colors='mediumorchid')
ax1_2.set_ylim(0., 3000.)
ax1_2.set_ylabel("Nb. of Object Motion", color='mediumorchid')
ax1_2.set_xlim(0., 50.)

ax = fig.add_axes([0.01, 0.55, .3, .3])
ax.imshow(arm, extent=[-1,1, -1, 1], alpha=.85)
ax.scatter(explored_states_history[50][:,0], explored_states_history[50][:,1], s=.5, alpha=.2)
ax.axis("off")

ax = fig.add_axes([0.175, 0.55, .3, .3])
ax.imshow(arm, extent=[-1,1, -1, 1], alpha=.85)
ax.scatter(explored_states_history[150][:,0], explored_states_history[150][:,1], s=.5, alpha=.2)
ax.axis("off")

ax = fig.add_axes([0.35, 0.55, .3, .3])
ax.imshow(arm, extent=[-1,1, -1, 1], alpha=.85)
ax.scatter(explored_states_history[250][:,0], explored_states_history[250][:,1], s=.5, alpha=.2)
ax.axis("off")

ax = fig.add_axes([0.525, 0.55, .3, .3])
ax.imshow(arm, extent=[-1,1, -1, 1], alpha=.85)
ax.scatter(explored_states_history[350][:,0], explored_states_history[350][:,1], s=.5, alpha=.2)
ax.axis("off")

ax = fig.add_axes([0.70, 0.55, .3, .3])
ax.imshow(arm, extent=[-1,1, -1, 1], alpha=.85)
ax.scatter(explored_states_history[450][:,0], explored_states_history[450][:,1], s=.5, alpha=.2)
ax.axis("off");

plt.tight_layout()
plt.savefig("Figures/exploration_plot_rge_efr_armball.pdf")
# Out:
# <img src="data:image/png;base64,..." width="950">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5cd8ed96e6d1> in <module>()
#      10 ax1.set_xlabel("Exploration epochs (x100)")
#      11 ax1.set_ylabel("KLC", color='royalblue')
# ---> 12 ax1.add_line(matplotlib.lines.Line2D([5,5],   [kls[5]+.05,7], linewidth=1))
#      13 ax1.add_line(matplotlib.lines.Line2D([15,15], [kls[15]+.05,7], linewidth=1))
#      14 ax1.add_line(matplotlib.lines.Line2D([25,25], [kls[25]+.05,7], linewidth=1))
#
# NameError: name 'matplotlib' is not defined
